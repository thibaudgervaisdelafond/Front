# %%
import pandas as pd
import unidecode

# %%
df_fifa = pd.read_csv(f'/Users/thibaudgervaisdelafond/code/thibaudgervaisdelafond/soccer_trade/raw_data/Fifa/FIFA_2015_processed.csv', sep = ',')

# %% [markdown]
# # 1

# %%
# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
#df_fifa = pd.read_csv(f'/Users/thibaudgervaisdelafond/code/thibaudgervaisdelafond/soccer_trade/raw_data/Fifa/FIFA_2015_processed.csv', sep = ',')
df = pd.read_csv('merged.csv')

# number of variable
categories=list(df[['passing', 'shooting', 'dribbling', 'pace', 'defending', 'physic']])
categories
# Out:
# ['passing', 'shooting', 'dribbling', 'pace', 'defending', 'physic']

# %%
name = df[df['name']=='youri tielemans']['name'].iloc[-1]
df[df['name']=='youri tielemans']
# Out:
#       Unnamed: 0        date             name  \
# 4              4  2017-07-01  youri tielemans
# 1455         238  2019-07-08  youri tielemans
#
#                                         link            from              to  \
# 4     /youri-tielemans/profil/spieler/249565  RSC Anderlecht       AS Monaco
# 1455  /youri-tielemans/profil/spieler/249565       AS Monaco  Leicester City
#
#         amount         bod nationality  year  ...  defending_sliding_tackle  \
# 4     25000000  1997/05/07     Belgium  2018  ...                        69
# 1455  45000000  1997/05/07     Belgium  2020  ...                        69
#
#       goalkeeping_diving  goalkeeping_handling goalkeeping_kicking  \
# 4                      6                     8                  10
# 1455                   6                     8                  10
#
#      goalkeeping_positioning goalkeeping_reflexes season_str_fifa  \
# 4                         14                   12            2017
# ...

# %%
df
# Out:
# (1849, 126)

# %%
df_test=df.groupby(by ='name')['date'].max()
df_test
# Out:
# name
# aaron lennon         2018-01-23
# aaron leya iseka     2018-07-01
# aaron mooy           2020-09-01
# aaron wan-bissaka    2019-07-01
# abdellah zoubir      2018-07-01
#                         ...
# zakaria labyad       2018-07-01
# zargo toure          2018-07-31
# zaydou youssouf      2019-07-05
# zinho gano           2018-07-02
# zinho vanheusden     2019-07-01
# Name: date, Length: 1606, dtype: object

# %%
df=df.sort_values('date').groupby(by='name').last().reset_index()
df[df['name']=='youri tielemans']
# Out:
#                  name  Unnamed: 0        date  \
# 1593  youri tielemans         238  2019-07-08
#
#                                         link       from              to  \
# 1593  /youri-tielemans/profil/spieler/249565  AS Monaco  Leicester City
#
#         amount         bod nationality  year  ...  defending_sliding_tackle  \
# 1593  45000000  1997/05/07     Belgium  2020  ...                        69
#
#       goalkeeping_diving  goalkeeping_handling goalkeeping_kicking  \
# 1593                   6                     8                  10
#
#      goalkeeping_positioning goalkeeping_reflexes season_str_fifa  \
# 1593                      14                   12            2019
#
#                                    merge_fifa diff_season_real  \
# 1593  youri tielemans_Belgium_1997/05/07_2019                1
#
#      diff_season_fifa
# 1593                1
#
# [1 rows x 126 columns]

# %%
import matplotlib.pyplot
import seaborn as sns
x0 = df[df['name'] == user_name]['overall'].values[0]
#plt.plot(x0)
#plt.scatter(x0, 20, color='red')
plt.hist(overall_list, bins=None, orientation ='horizontal')
plt.axhline(x0,xmax=0.26, color='red')

# %%
user_name='steve mandanda'
x0 = df[df['name'] == user_name]['overall'].values[0]
print(x0)
fig, ax = plt.subplots(figsize=(5,5))
print(ax.lines[0].get_data())
sns.histplot(overall_list, kde=True, ax=ax)
# Out:
# 85
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/_6/jmxrkd512rs41z1979gv0yjr0000gn/T/ipykernel_17892/3490065786.py in <module>
#       3 print(x0)
#       4 fig, ax = plt.subplots(figsize=(5,5))
# ----> 5 print(ax.lines[0].get_data())
#       6 sns.histplot(overall_list, kde=True, ax=ax)
#
# IndexError: list index out of range

# %%
x0 = df[df['name'] == user_name]['overall'].values[0]
    
fig, ax = plt.subplots(figsize=(5,5))


plt.xlabel("Overall")
sns.histplot(overall_list, kde=True, ax=ax)
data_x, data_y = ax.lines[0].get_data()
plt.scatter(x0, np.interp(x0,data_x, data_y), color='red', linewidths=10 )

# %%
x0 = df[df['name'] == user_name]['overall'].values[0]
    
fig, ax = plt.subplots(figsize=(5,5))
    
plt.xlabel("Overall")
sns.histplot(overall_list, kde=True, ax=ax)
plt.scatter(x0, yi, color='red', linewidths=10 )

data_x, data_y = ax.lines[0].get_data()
y1 = np.interp(x0,data_x, data_y)
y1
# Out:
# 3.6543187153948535

# %%
x0
# Out:
# 85

# %%
# Out:
# 3.6543187153948535

# %% [markdown]
# # 2

# %%
for i in df:
    print(i)
# Out:
# name
# Unnamed: 0
# date
# link
# from
# to
# amount
# bod
# nationality
# year
# year_str
# year_ly
# year_ly_str
# merge
# merge_ly
# full_name
# birthday_GMT
# season_real
# nationality_real
# position
# minutes_played_overall
# minutes_played_home
# minutes_played_away
# appearances_overall
# appearances_home
# appearances_away
# goals_overall
# goals_home
# goals_away
# assists_overall
# assists_home
# assists_away
# penalty_goals
# penalty_misses
# clean_sheets_overall
# clean_sheets_home
# clean_sheets_away
# conceded_overall
# conceded_home
# conceded_away
# yellow_cards_overall
# red_cards_overall
# rank_in_league_top_attackers
# rank_in_league_top_midfielders
# rank_in_league_top_defenders
# goals_involved_per_90_overall
# assists_per_90_overall
# goals_per_90_overall
# goals_per_90_home
# goals_per_90_away
# min_per_goal_overall
# conceded_per_90_overall
# min_per_conceded_overall
# min_per_match
# min_per_card_overall
# min_per_assist_overall
# cards_per_90_overall
# ...

# %%
user_name='steve mandanda'
if 'Goalkeeper' in df[df['name'] == user_name]['position'].values[0]:
    loc_=df[df['name'] == user_name][['gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning']]
else:
    loc_=df[df['name'] == user_name][['passing', 'shooting', 'dribbling', 'pace', 'defending', 'physic']]
    
loc_
# Out:
#       gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 1468         86           80          79           85        48
#
#       gk_positioning
# 1468              81

# %%
league= list(df['league_name'].unique())
league_player= df[df['name']== user_name]['league_name'].values[0]
    
if league_player in league:
    amount_list=list(df[df['league_name']== league_player]['amount'].values)
    
list_=[]
#for amount in amount_list:
    #list_.append(amount/1000000)
    
x0 = df[df['name'] == user_name]['amount'].values[0]
    
fig, ax = plt.subplots(figsize=(5,5))
    

plt.xlabel("Market cap")
sns.histplot(amount_list, kde=True, ax=ax)

data_x, data_y = ax.lines[0].get_data()
plt.scatter(x0, np.interp(x0,data_x, data_y), color='red', linewidths=10)

xlabels = ['{:,.2f}'.format(x) + 'M' for x in ax.get_xticks()/10e6]
ax.set_xticklabels(xlabels)

plt.legend(['Market cap repartition'])
# Out:
# /var/folders/_6/jmxrkd512rs41z1979gv0yjr0000gn/T/ipykernel_17892/2823567019.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xlabels)

# %%
df[df['league_name']=='French Ligue 1'].sort_values(by='amount', ascending=False)
# Out:
#                      name  Unnamed: 0        date  \
# 811         kylian mbappe         607  2018-07-01
# 1495         thomas lemar         608  2018-07-01
# 1484      tanguy ndombele         205  2019-07-02
# 182        benjamin mendy         344  2017-07-24
# 69    alexandre lacazette         224  2017-07-05
# ...                   ...         ...         ...
# 254        chris philipps         599  2018-02-02
# 502     francois bellugou         189  2018-07-01
# 759       karim coulibaly         185  2017-07-01
# 77            aliou cisse         367  2019-07-30
# 1553       vincent marcel         496  2019-09-02
#
#                                            link          from  \
# 811        /kylian-mbappe/profil/spieler/342229     AS Monaco
# 1495        /thomas-lemar/profil/spieler/205562     AS Monaco
# 1484     /tanguy-ndombele/profil/spieler/450936  Ol. Lyonnais
# 182       /benjamin-mendy/profil/spieler/157495     AS Monaco
# ...

# %%
amount_list=np.array(amount_list)/1000000
sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_6/jmxrkd512rs41z1979gv0yjr0000gn/T/ipykernel_17892/3041387731.py in <module>
#       1 amount_list=np.array(amount_list)/1000000
# ----> 2 amount_list.sorted()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sorted'

# %%
plt.hist(amount_list)
# Out:
# (array([79., 21., 10.,  5.,  1.,  2.,  2.,  0.,  1.,  1.]),
#  array([  0.225 ,  13.7025,  27.18  ,  40.6575,  54.135 ,  67.6125,
#          81.09  ,  94.5675, 108.045 , 121.5225, 135.    ]),
#  <BarContainer object of 10 artists>)

# %%
prediction_df= pd.read_csv('data_avec_prediction_v3.csv')

# %%
for x in prediction_df:
    print(x)
# Out:
# Unnamed: 0
# age
# height_cm
# weight_kg
# club_name
# league_name
# league_rank
# overall
# potential
# pace
# shooting
# passing
# dribbling
# defending
# physic
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# mentality_aggression
# mentality_interceptions
# mentality_positioning
# mentality_vision
# mentality_penalties
# defending_marking
# defending_standing_tackle
# defending_sliding_tackle
# minutes_played_overall
# min_per_goal_overall
# assists_overall
# appearances_overall
# goals_overall
# assists_overall.1
# clean_sheets_overall
# conceded_overall
# yellow_cards_overall
# red_cards_overall
# ...

# %%
a=str(100000)
for i in a:
    print(i)
# Out:
# 1
# 0
# 0
# 0
# 0
# 0

# %%
a=10000000
"{:,}".format(a)
# Out:
# '10,000,000'

# %%
for i in df:
    print(i)
# Out:
# name
# Unnamed: 0
# date
# link
# from
# to
# amount
# bod
# nationality
# year
# year_str
# year_ly
# year_ly_str
# merge
# merge_ly
# full_name
# birthday_GMT
# season_real
# nationality_real
# position
# minutes_played_overall
# minutes_played_home
# minutes_played_away
# appearances_overall
# appearances_home
# appearances_away
# goals_overall
# goals_home
# goals_away
# assists_overall
# assists_home
# assists_away
# penalty_goals
# penalty_misses
# clean_sheets_overall
# clean_sheets_home
# clean_sheets_away
# conceded_overall
# conceded_home
# conceded_away
# yellow_cards_overall
# red_cards_overall
# rank_in_league_top_attackers
# rank_in_league_top_midfielders
# rank_in_league_top_defenders
# goals_involved_per_90_overall
# assists_per_90_overall
# goals_per_90_overall
# goals_per_90_home
# goals_per_90_away
# min_per_goal_overall
# conceded_per_90_overall
# min_per_conceded_overall
# min_per_match
# min_per_card_overall
# min_per_assist_overall
# cards_per_90_overall
# ...

# %%
df[df['to']=='Barcelone']
# Out:
#                    name  Unnamed: 0        date  \
# 129   antoine griezmann         287  2019-07-14
# 508     frenkie de jong           0  2019-07-01
# 1132      nelson semedo         294  2017-07-14
# 1202    ousmane dembele         443  2017-08-25
# 1246  philippe coutinho         528  2018-01-08
#
#                                           link             from         to  \
# 129   /antoine-griezmann/profil/spieler/125781  Atlético Madrid  Barcelone
# 508     /frenkie-de-jong/profil/spieler/326330             Ajax  Barcelone
# 1132      /nelson-semedo/profil/spieler/231572          Benfica  Barcelone
# 1202    /ousmane-dembele/profil/spieler/288230    Bor. Dortmund  Barcelone
# 1246   /philippe-coutinho/profil/spieler/80444     FC Liverpool  Barcelone
#
#          amount         bod  nationality  year  ...  defending_sliding_tackle  \
# 129   120000000  1991/03/21       France  2020  ...                        44
# ...
